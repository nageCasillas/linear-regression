# %%
# importing librarys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# read the dataset
df=pd.read_csv('dataset/height-weight.csv')

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
# check for null in dataframe
df.isnull().sum()
# Out:
# Weight    0
# Height    0
# dtype: int64

# %%
df.shape
# Out:
# (23, 2)

# %%
# creating dependent and independent variables.
X = df[['Weight']]
y = df['Height']

# %%
# splitting to train test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
## Standardize the dataset
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
# initalising elasticnet function
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
elastic=ElasticNet()

# %%
# fitting elastic with training dataset
elastic.fit(X_train, y_train)
# Out:
# ElasticNet()

# %%
# predicting with testing data
y_pred=elastic.predict(X_test)

# %%
# analysing the y test and y pred, if it follows a linear pattern than its a good result
plt.scatter(y_test, y_pred)

# %%
# printing accuracy
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.6112442515757881

# %%
# initalising elasticnet cv function
from sklearn.linear_model import ElasticNetCV
elasticcv=ElasticNetCV(cv=5)

# %%
# fitting elastic cv with training dataset
elasticcv.fit(X_train, y_train)
# Out:
# ElasticNetCV(cv=5)

# %%
# predicting with testing data
y_pred=elasticcv.predict(X_test)

# %%
# analysing the y test and y pred, if it follows a linear pattern than its a good result
plt.scatter(y_test, y_pred)

# %%
# printing accuracy
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.771795216865043
