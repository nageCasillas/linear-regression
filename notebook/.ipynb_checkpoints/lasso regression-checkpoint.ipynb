# %%
# importing librarys
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# read the dataset
df=pd.read_csv('dataset/height-weight.csv')

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
# check for null in dataframe
df.isnull().sum()
# Out:
# Weight    0
# Height    0
# dtype: int64

# %%
df.shape
# Out:
# (23, 2)

# %%
# creating dependent and independent variables.
X = df[['Weight']]
y = df['Height']

# %%
# splitting to train test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
## Standardize the dataset
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
# initalising lasso function
lasso=Lasso()

# %%
# fitting the lasso with train dataset
lasso.fit(X_train,y_train)
# Out:
# Lasso()

# %%
# predicting with testing data
y_pred=lasso.predict(X_test)

# %%
# analysing the y test and y pred, if it follows a linear pattern than its a good result
plt.scatter(y_test, y_pred)

# %%
# printing accuracy
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.7585298327733477

# %%
# initalising lasso cv function
from sklearn.linear_model import LassoCV
lassocv=LassoCV(cv=5)

# %%
# fitting the lasso cv with train dataset
lassocv.fit(X_train,y_train)
# Out:
# LassoCV(cv=5)

# %%
# predicting with testing data
y_pred=lassocv.predict(X_test)

# %%
# analysing the y test and y pred, if it follows a linear pattern than its a good result
plt.scatter(y_test, y_pred)

# %%
# printing accuracy
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.7767030306625153
